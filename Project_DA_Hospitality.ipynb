# %%
** Data Analysis of Atliq Hotels & companies

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df_bookings=pd.read_csv("fact_bookings.csv")
df_bookings.head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.isna().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                3
# room_category            0
# booking_platform         0
# ratings_given        77907
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
df_bookings[["ratings_given","booking_status"]]
# Out:
#         ratings_given booking_status
# 0                 1.0    Checked Out
# 1                 NaN      Cancelled
# 2                 5.0    Checked Out
# 3                 NaN      Cancelled
# 4                 5.0    Checked Out
# ...               ...            ...
# 134585            2.0    Checked Out
# 134586            2.0    Checked Out
# 134587            NaN      Cancelled
# 134588            2.0    Checked Out
# 134589            NaN      Cancelled
#
# [134590 rows x 2 columns]

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings["room_category"].value_counts()
# Out:
# room_category
# RT2    49505
# RT1    38446
# RT3    30566
# RT4    16073
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings["booking_platform"].value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings["booking_platform"].value_counts().plot(kind='bar')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'others'),
#   Text(1, 0, 'makeyourtrip'),
#   Text(2, 0, 'logtrip'),
#   Text(3, 0, 'direct online'),
#   Text(4, 0, 'tripster'),
#   Text(5, 0, 'journey'),
#   Text(6, 0, 'direct offline')])

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_date=pd.read_csv("dim_date.csv")
df_hotels=pd.read_csv("dim_hotels.csv")
df_rooms=pd.read_csv("dim_rooms.csv")
df_agg_bookings=pd.read_csv("fact_aggregated_bookings.csv")

# %%
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday

# %%
df_hotels.head(5)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_hotels.property_name.value_counts()
# Out:
# property_name
# Atliq Grands     4
# Atliq Exotica    4
# Atliq City       4
# Atliq Blu        4
# Atliq Bay        4
# Atliq Palace     4
# Atliq Seasons    1
# Name: count, dtype: int64

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts()
# Out:
# city
# Mumbai       8
# Hyderabad    6
# Bangalore    6
# Delhi        5
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().plot(kind='bar')
plt.xticks(rotation=45)
plt.title("City wise Booking Data")
plt.show()

# %%
df_rooms.head(5)
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_rooms.room_class.value_counts()
# Out:
# room_class
# Standard        1
# Elite           1
# Premium         1
# Presidential    1
# Name: count, dtype: int64

# %%
df_agg_bookings.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agg_bookings["successful_bookings"].sum()
# Out:
# np.int64(134833)

# %%
df_agg_bookings["room_category"].value_counts()
# Out:
# room_category
# RT1    2300
# RT2    2300
# RT3    2300
# RT4    2300
# Name: count, dtype: int64

# %%
# Data Cleaning

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings=df_bookings[df_bookings.no_guests>0]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134578, 12)

# %%
df_bookings.revenue_generated.min(), df_bookings.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.std()
# Out:
# (np.float64(15378.036937686695), np.float64(93040.1549314641))

# %%
avg, std = df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.std()

# %%
avg
# Out:
# np.float64(15378.036937686695)

# %%
higher_limit=avg + 3*std
higher_limit
# Out:
# np.float64(294498.50173207896)

# %%
lower_limit = avg - 3*std
lower_limit
# Out:
# np.float64(-263742.4278567056)

# %%
df_bookings[df_bookings.revenue_generated<0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
# To find outlier
df_bookings[df_bookings.revenue_generated > higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings[df_bookings.revenue_generated < lower_limit]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings=df_bookings[df_bookings.revenue_generated<higher_limit]
df_bookings.shape
# Out:
# (134573, 12)

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
avg=df_bookings.revenue_realized.mean()
std=df_bookings.revenue_realized.std()

# %%
higher_limit=avg+3*std
lower_limit=avg-3*std

# %%
df_bookings[df_bookings.revenue_realized > higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
df_bookings[df_bookings.room_category=='RT4'].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
# To check Null value:-
df_bookings.isna().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
# Data Transformation

# %%
df_agg_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0

# %%
df_agg_bookings["occ_pct"]=df_agg_bookings['successful_bookings']/df_agg_bookings['capacity']

# %%
df_agg_bookings["occ"]= df_agg_bookings.apply(lambda x:x['successful_bookings']/x['capacity'], axis=1)

# %%
df_agg_bookings.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#     occ_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667
# 3  1.578947

# %%
df_agg_bookings['occ_pct']=df_agg_bookings['occ_pct'].apply(lambda x:round(x*100,2))
df_agg_bookings.head(2)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
#
#    occ_pct
# 0    83.33
# 1    93.33

# %%
# Average Occupancy rate in each of the room category:

# %%
df_agg_bookings.groupby("room_category")["occ_pct"].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occ_pct, dtype: float64

# %%
df_agg_bookings.groupby("room_category")["successful_bookings"].sum()
# Out:
# room_category
# RT1    38651
# RT2    49534
# RT3    30566
# RT4    16082
# Name: successful_bookings, dtype: int64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df=pd.merge(df_agg_bookings, df_rooms, left_on="room_category", right_on="room_id")
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    occ_pct       occ room_id room_class
# 0    83.33  0.833333     RT1   Standard
# 1    93.33  0.933333     RT1   Standard
# 2    76.67  0.766667     RT1   Standard
# 3   157.89  1.578947     RT1   Standard

# %%
df.groupby("room_class")["occ_pct"].mean().round(2)
# Out:
# room_class
# Elite           58.04
# Premium         58.03
# Presidential    59.30
# Standard        58.22
# Name: occ_pct, dtype: float64

# %%
df.drop("room_id", axis=1, inplace=True)
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    occ_pct       occ room_class
# 0    83.33  0.833333   Standard
# 1    93.33  0.933333   Standard
# 2    76.67  0.766667   Standard
# 3   157.89  1.578947   Standard

# %%
# City wise occupancy

# %%
df_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct       occ room_class
# 0    83.33  0.833333   Standard
# 1    93.33  0.933333   Standard
# 2    76.67  0.766667   Standard

# %%
df1=pd.merge(df,df_hotels, on="property_id")
df1.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct       occ room_class  property_name  category       city
# 0    83.33  0.833333   Standard  Atliq Exotica    Luxury     Mumbai
# 1    93.33  0.933333   Standard      Atliq Bay    Luxury  Bangalore
# 2    76.67  0.766667   Standard   Atliq Palace  Business  Bangalore

# %%
df1.groupby("city")["occ_pct"].mean().round(2).plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %%
# When is the occupancy is better? Weekday or Weekend?

# %%
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday

# %%
df2=pd.merge(df1,df_date,left_on="check_in_date", right_on="date")
df2.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
#
#    occ_pct       occ room_class property_name  category       city       date  \
# 0    51.72  0.517241    Premium  Atliq Palace  Business  Bangalore  10-May-22
# 1    63.33  0.633333   Standard    Atliq City  Business  Hyderabad  10-May-22
# 2    60.00  0.600000   Standard     Atliq Bay    Luxury  Bangalore  10-May-22
#
#    mmm yy week no  day_type
# 0  May 22    W 20  weekeday
# 1  May 22    W 20  weekeday
# 2  May 22    W 20  weekeday

# %%
df2.groupby("day_type")["occ_pct"].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: occ_pct, dtype: float64

# %%
df2.groupby("day_type")["occ_pct"].mean().round(2).plot(kind="bar")
# Out:
# <Axes: xlabel='day_type'>

# %%
df2.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
#
#    occ_pct       occ room_class property_name  category       city       date  \
# 0    51.72  0.517241    Premium  Atliq Palace  Business  Bangalore  10-May-22
# 1    63.33  0.633333   Standard    Atliq City  Business  Hyderabad  10-May-22
# 2    60.00  0.600000   Standard     Atliq Bay    Luxury  Bangalore  10-May-22
#
#    mmm yy week no  day_type
# 0  May 22    W 20  weekeday
# 1  May 22    W 20  weekeday
# 2  May 22    W 20  weekeday

# %%
df2["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_june= df2[df2["mmm yy"]=="Jun 22"]
df_june.head(2)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        19562     10-Jun-22           RT1                   19      30.0
#
#       occ_pct       occ room_class  property_name category       city  \
# 2200    66.67  0.666667   Standard  Atliq Exotica   Luxury     Mumbai
# 2201    63.33  0.633333   Standard      Atliq Bay   Luxury  Bangalore
#
#            date  mmm yy week no  day_type
# 2200  10-Jun-22  Jun 22    W 24  weekeday
# 2201  10-Jun-22  Jun 22    W 24  weekeday

# %%
df_june.groupby("city")["occ_pct"].mean().round(2).sort_values(ascending=False)
# Out:
# city
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.58
# Name: occ_pct, dtype: float64

# %%
df_june.groupby("city")["occ_pct"].mean().round(2).plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
# add new data to dataframe

# %%
df_august=pd.read_csv("new_data_august.csv")
df_august.head(3)
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67

# %%
df2.columns
# Out:
# Index(['property_id', 'check_in_date', 'room_category', 'successful_bookings',
#        'capacity', 'occ_pct', 'occ', 'room_class', 'property_name', 'category',
#        'city', 'date', 'mmm yy', 'week no', 'day_type'],
#       dtype='object')

# %%
df_august.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df2.shape
# Out:
# (6500, 15)

# %%
df_august.shape
# Out:
# (7, 13)

# %%
latest_df=pd.concat([df2,df_august],ignore_index=True, axis=0)
latest_df.tail(3)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
#       occ_pct  occ room_class  property_name  category       city date  \
# 6504      NaN  NaN   Standard     Atliq City  Business  Bangalore  NaN
# 6505      NaN  NaN   Standard      Atliq Blu    Luxury     Mumbai  NaN
# 6506      NaN  NaN   Standard  Atliq Seasons  Business     Mumbai  NaN
#
#       mmm yy week no  day_type   occ%
# 6504  Aug-22    W 32  weekeday  76.92
# 6505  Aug-22    W 32  weekeday  69.23
# 6506  Aug-22    W 32  weekeday  62.50

# %%
latest_df.shape
# Out:
# (6507, 16)

# %%
** Print revenue realized per city**

# %%
df_bookings.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized
# 1               9100              3640
# 4              10920             10920
# 5               9100              9100

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df_merge=pd.merge(df_bookings,df_hotels, on="property_id")
df_merge.tail(3)
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 134570   Jul312217564RT48        17564     30-07-22      31-07-22
# 134571   Jul312217564RT49        17564     29-07-22      31-07-22
# 134572  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 134570      2/8/2022        1.0           RT4         tripster            NaN
# 134571      1/8/2022        2.0           RT4          logtrip            2.0
# 134572      1/8/2022        2.0           RT4     makeyourtrip            NaN
#
#        booking_status  revenue_generated  revenue_realized  property_name  \
# 134570      Cancelled              32300             12920  Atliq Seasons
# 134571    Checked Out              32300             32300  Atliq Seasons
# 134572      Cancelled              32300             12920  Atliq Seasons
#
#         category    city
# 134570  Business  Mumbai
# 134571  Business  Mumbai
# ...

# %%
df_merge.groupby("city")["revenue_realized"].sum().sort_values(ascending=False)
# Out:
# city
# Mumbai       668569251
# Bangalore    420383550
# Hyderabad    325179310
# Delhi        294404488
# Name: revenue_realized, dtype: int64

# %%
**Revenue per Month

# %%
df_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df_revenue_month=pd.merge(df_merge,df_date, left_on="check_in_date", right_on="date")
df_revenue_month.head(5)
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized, property_name, category, city, date, mmm yy, week no, day_type]
# Index: []

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  object
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
df_date["date"]=pd.to_datetime(df_date["date"])
df_date.head(3)
# Out:
# C:\Users\pgiri\AppData\Local\Temp\ipykernel_17608\1847724004.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_date["date"]=pd.to_datetime(df_date["date"])
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday

# %%
df_merge["check_in_date"]=pd.to_datetime(df_merge["check_in_date"], format='mixed')
df_merge.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-01-05      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-01-05      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-01-05      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  datetime64[ns]
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_revenue_month=pd.merge(df_merge,df_date, left_on="check_in_date", right_on="date")
df_revenue_month.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May052216558RT11        16558     15-04-22    2022-05-05      7/5/2022
# 1  May052216558RT12        16558     30-04-22    2022-05-05      7/5/2022
# 2  May052216558RT13        16558     1/5/2022    2022-05-05      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        3.0           RT1         tripster            5.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        3.0           RT1   direct offline            5.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0              10010             10010  Atliq Grands   Luxury  Delhi
# 1               9100              3640  Atliq Grands   Luxury  Delhi
# 2              10010             10010  Atliq Grands   Luxury  Delhi
#
#         date  mmm yy week no  day_type
# 0 2022-05-05  May 22    W 19  weekeday
# ...

# %%
df_revenue_month.groupby("mmm yy")["revenue_realized"].sum().sort_values(ascending=False)
# Out:
# mmm yy
# May 22    408375641
# Jul 22    389940912
# Jun 22    377191229
# Name: revenue_realized, dtype: int64
